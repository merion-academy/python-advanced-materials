# %% [markdown]
# ## Введение в асинхронное программирование
# - зачем нужно асинхронное программирование
# - асинхронное выполнение задач в Python

# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    datefmt="%Y-%m-%d %H:%M:%S",
    format="[%(asctime)s.%(msecs)03d] %(module)s:%(lineno)d %(levelname)s - %(message)s",
)

log = logging.getLogger(__name__)

# %%
log.info("Starting")
# Out:
# [2023-08-06 13:35:32.118] 2904165575:1 INFO - Starting

# %%
from time import sleep


def get_stocks():
    log.info("get stocks")
    sleep(1)
    log.info("stocks ok")


def get_weather():
    log.info("get weather")
    sleep(1)
    log.info("weather ok")

# %%
def main():
    get_stocks()
    get_weather()

main()
# Out:
# [2023-08-06 13:46:07.575] 251705528:5 INFO - get stocks
# [2023-08-06 13:46:08.584] 251705528:7 INFO - stocks ok
# [2023-08-06 13:46:08.585] 251705528:11 INFO - get weather
# [2023-08-06 13:46:09.590] 251705528:13 INFO - weather ok

# %%
from asyncio import sleep


async def get_stocks():
    log.info("get stocks")
    await sleep(1)
    log.info("stocks ok")


async def get_weather():
    log.info("get weather")
    await sleep(1)
    log.info("weather ok")

# %%
async def main():
    coro = get_stocks() 
    log.info("created coro %s", coro)
    await coro
    await get_weather()


await main()
# Out:
# [2023-08-06 13:55:54.198] 3138204583:3 INFO - created coro <coroutine object get_stocks at 0x106613dc0>
# [2023-08-06 13:55:54.200] 4076986493:5 INFO - get stocks
# [2023-08-06 13:55:55.203] 4076986493:7 INFO - stocks ok
# [2023-08-06 13:55:55.204] 4076986493:11 INFO - get weather
# [2023-08-06 13:55:56.206] 4076986493:13 INFO - weather ok

# %%
import asyncio

async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)
    await asyncio.gather(
        coro,
        get_weather(),
    )
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:00:10.912] 2120146542:4 INFO - Start
# [2023-08-06 14:00:10.914] 2120146542:6 INFO - created coro <coroutine object get_stocks at 0x106613dc0>
# [2023-08-06 14:00:10.916] 4076986493:5 INFO - get stocks
# [2023-08-06 14:00:10.916] 4076986493:11 INFO - get weather
# [2023-08-06 14:00:11.917] 4076986493:7 INFO - stocks ok
# [2023-08-06 14:00:11.918] 4076986493:13 INFO - weather ok
# [2023-08-06 14:00:11.920] 2120146542:11 INFO - Done

# %%
import asyncio


async def get_stocks():
    log.info("get stocks")
    await asyncio.sleep(1)
    log.info("stocks ok")
    return {"stocks": []}


async def get_weather():
    log.info("get weather")
    await asyncio.sleep(1)
    log.info("weather ok")
    return {"weather": {}}

# %%
import asyncio

async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)
    stocks, weather = await asyncio.gather(
        coro,
        get_weather(),
    )
    log.info("Stocks: %s", stocks)
    log.info("Weather: %s", weather)
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:06:38.297] 3715711119:4 INFO - Start
# [2023-08-06 14:06:38.300] 3715711119:6 INFO - created coro <coroutine object get_stocks at 0x10791e740>
# [2023-08-06 14:06:38.301] 1712840538:5 INFO - get stocks
# [2023-08-06 14:06:38.302] 1712840538:12 INFO - get weather
# [2023-08-06 14:06:39.304] 1712840538:7 INFO - stocks ok
# [2023-08-06 14:06:39.306] 1712840538:14 INFO - weather ok
# [2023-08-06 14:06:39.307] 3715711119:11 INFO - Stocks: {'stocks': []}
# [2023-08-06 14:06:39.308] 3715711119:12 INFO - Weather: {'weather': {}}
# [2023-08-06 14:06:39.309] 3715711119:13 INFO - Done

# %%
import asyncio


async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)

    async with asyncio.TaskGroup() as tg:
        tg.create_task(coro)
        tg.create_task(get_weather())

    # log.info("Stocks: %s", stocks)
    # log.info("Weather: %s", weather)
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:10:52.907] 1602770809:5 INFO - Start
# [2023-08-06 14:10:52.917] 1602770809:7 INFO - created coro <coroutine object get_stocks at 0x10791e980>
# [2023-08-06 14:10:52.917] 1712840538:5 INFO - get stocks
# [2023-08-06 14:10:52.918] 1712840538:12 INFO - get weather
# [2023-08-06 14:10:53.919] 1712840538:7 INFO - stocks ok
# [2023-08-06 14:10:53.920] 1712840538:14 INFO - weather ok
# [2023-08-06 14:10:53.928] 1602770809:15 INFO - Done

# %%
import asyncio


async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)

    async with asyncio.TaskGroup() as tg:
        task_stocks = tg.create_task(coro)
        task_weather = tg.create_task(get_weather())

    stocks = task_stocks.result()
    log.info("Stocks: %s", stocks)
    weather = task_weather.result()
    log.info("Weather: %s", weather)
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:12:02.598] 1230269060:5 INFO - Start
# [2023-08-06 14:12:02.601] 1230269060:7 INFO - created coro <coroutine object get_stocks at 0x10791e500>
# [2023-08-06 14:12:02.601] 1712840538:5 INFO - get stocks
# [2023-08-06 14:12:02.602] 1712840538:12 INFO - get weather
# [2023-08-06 14:12:03.603] 1712840538:7 INFO - stocks ok
# [2023-08-06 14:12:03.603] 1712840538:14 INFO - weather ok
# [2023-08-06 14:12:03.604] 1230269060:14 INFO - Stocks: {'stocks': []}
# [2023-08-06 14:12:03.604] 1230269060:16 INFO - Weather: {'weather': {}}
# [2023-08-06 14:12:03.605] 1230269060:17 INFO - Done

# %%
import asyncio


async def get_stocks():
    log.info("get stocks")
    await asyncio.sleep(1.001)
    log.info("stocks ok")
    return {"stocks": []}


async def get_weather():
    log.info("get weather")
    await asyncio.sleep(1)
    log.info("weather ok")
    return {"weather": {}}


async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)

    async with asyncio.TaskGroup() as tg:
        task_stocks = tg.create_task(coro)
        task_weather = tg.create_task(get_weather())

    stocks = task_stocks.result()
    log.info("Stocks: %s", stocks)
    weather = task_weather.result()
    log.info("Weather: %s", weather)
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:18:42.372] 2707156705:19 INFO - Start
# [2023-08-06 14:18:42.374] 2707156705:21 INFO - created coro <coroutine object get_stocks at 0x10791f280>
# [2023-08-06 14:18:42.374] 2707156705:5 INFO - get stocks
# [2023-08-06 14:18:42.375] 2707156705:12 INFO - get weather
# [2023-08-06 14:18:43.377] 2707156705:14 INFO - weather ok
# [2023-08-06 14:18:43.378] 2707156705:7 INFO - stocks ok
# [2023-08-06 14:18:43.391] 2707156705:28 INFO - Stocks: {'stocks': []}
# [2023-08-06 14:18:43.392] 2707156705:30 INFO - Weather: {'weather': {}}
# [2023-08-06 14:18:43.392] 2707156705:31 INFO - Done

# %%
import asyncio


async def get_stocks():
    log.info("get stocks")
    for s in range(1, 6):
        log.info("s %s ^ 3 = %s", s, s ** 3)
        await asyncio.sleep(0.001)
    log.info("stocks ok")
    return {"stocks": []}


async def get_weather():
    log.info("get weather")
    for w in range(1, 51):
        log.info("w %s ^ 2 = %s", w, w ** 2)
        await asyncio.sleep(0)
    log.info("weather ok")
    return {"weather": {}}


async def main():
    log.info("Start")
    coro = get_stocks() 
    log.info("created coro %s", coro)

    async with asyncio.TaskGroup() as tg:
        task_stocks = tg.create_task(coro)
        task_weather = tg.create_task(get_weather())

    stocks = task_stocks.result()
    log.info("Stocks: %s", stocks)
    weather = task_weather.result()
    log.info("Weather: %s", weather)
    log.info("Done")


await main()
# Out:
# [2023-08-06 14:25:54.643] 2303383967:23 INFO - Start
# [2023-08-06 14:25:54.644] 2303383967:25 INFO - created coro <coroutine object get_stocks at 0x107e284f0>
# [2023-08-06 14:25:54.648] 2303383967:5 INFO - get stocks
# [2023-08-06 14:25:54.649] 2303383967:7 INFO - s 1 ^ 3 = 1
# [2023-08-06 14:25:54.650] 2303383967:14 INFO - get weather
# [2023-08-06 14:25:54.650] 2303383967:16 INFO - w 1 ^ 2 = 1
# [2023-08-06 14:25:54.651] 2303383967:16 INFO - w 2 ^ 2 = 4
# [2023-08-06 14:25:54.652] 2303383967:16 INFO - w 3 ^ 2 = 9
# [2023-08-06 14:25:54.653] 2303383967:7 INFO - s 2 ^ 3 = 8
# [2023-08-06 14:25:54.654] 2303383967:16 INFO - w 4 ^ 2 = 16
# [2023-08-06 14:25:54.654] 2303383967:16 INFO - w 5 ^ 2 = 25
# [2023-08-06 14:25:54.661] 2303383967:16 INFO - w 6 ^ 2 = 36
# [2023-08-06 14:25:54.662] 2303383967:16 INFO - w 7 ^ 2 = 49
# [2023-08-06 14:25:54.662] 2303383967:7 INFO - s 3 ^ 3 = 27
# [2023-08-06 14:25:54.663] 2303383967:16 INFO - w 8 ^ 2 = 64
# [2023-08-06 14:25:54.664] 2303383967:16 INFO - w 9 ^ 2 = 81
# [2023-08-06 14:25:54.664] 2303383967:16 INFO - w 10 ^ 2 = 100
# [2023-08-06 14:25:54.670] 2303383967:16 INFO - w 11 ^ 2 = 121
# [2023-08-06 14:25:54.677] 2303383967:7 INFO - s 4 ^ 3 = 64
# [2023-08-06 14:25:54.678] 2303383967:16 INFO - w 12 ^ 2 = 144
# [2023-08-06 14:25:54.679] 2303383967:16 INFO - w 13 ^ 2 = 169
# [2023-08-06 14:25:54.679] 2303383967:16 INFO - w 14 ^ 2 = 196
# [2023-08-06 14:25:54.679] 2303383967:16 INFO - w 15 ^ 2 = 225
# [2023-08-06 14:25:54.680] 2303383967:7 INFO - s 5 ^ 3 = 125
# [2023-08-06 14:25:54.680] 2303383967:16 INFO - w 16 ^ 2 = 256
# [2023-08-06 14:25:54.681] 2303383967:16 INFO - w 17 ^ 2 = 289
# [2023-08-06 14:25:54.681] 2303383967:16 INFO - w 18 ^ 2 = 324
# [2023-08-06 14:25:54.682] 2303383967:16 INFO - w 19 ^ 2 = 361
# [2023-08-06 14:25:54.682] 2303383967:9 INFO - stocks ok
# [2023-08-06 14:25:54.683] 2303383967:16 INFO - w 20 ^ 2 = 400
# [2023-08-06 14:25:54.683] 2303383967:16 INFO - w 21 ^ 2 = 441
# [2023-08-06 14:25:54.684] 2303383967:16 INFO - w 22 ^ 2 = 484
# [2023-08-06 14:25:54.685] 2303383967:16 INFO - w 23 ^ 2 = 529
# [2023-08-06 14:25:54.686] 2303383967:16 INFO - w 24 ^ 2 = 576
# [2023-08-06 14:25:54.687] 2303383967:16 INFO - w 25 ^ 2 = 625
# [2023-08-06 14:25:54.687] 2303383967:16 INFO - w 26 ^ 2 = 676
# [2023-08-06 14:25:54.687] 2303383967:16 INFO - w 27 ^ 2 = 729
# [2023-08-06 14:25:54.688] 2303383967:16 INFO - w 28 ^ 2 = 784
# [2023-08-06 14:25:54.688] 2303383967:16 INFO - w 29 ^ 2 = 841
# [2023-08-06 14:25:54.688] 2303383967:16 INFO - w 30 ^ 2 = 900
# [2023-08-06 14:25:54.689] 2303383967:16 INFO - w 31 ^ 2 = 961
# [2023-08-06 14:25:54.689] 2303383967:16 INFO - w 32 ^ 2 = 1024
# [2023-08-06 14:25:54.689] 2303383967:16 INFO - w 33 ^ 2 = 1089
# [2023-08-06 14:25:54.690] 2303383967:16 INFO - w 34 ^ 2 = 1156
# [2023-08-06 14:25:54.691] 2303383967:16 INFO - w 35 ^ 2 = 1225
# [2023-08-06 14:25:54.691] 2303383967:16 INFO - w 36 ^ 2 = 1296
# [2023-08-06 14:25:54.691] 2303383967:16 INFO - w 37 ^ 2 = 1369
# [2023-08-06 14:25:54.692] 2303383967:16 INFO - w 38 ^ 2 = 1444
# [2023-08-06 14:25:54.692] 2303383967:16 INFO - w 39 ^ 2 = 1521
# [2023-08-06 14:25:54.692] 2303383967:16 INFO - w 40 ^ 2 = 1600
# [2023-08-06 14:25:54.693] 2303383967:16 INFO - w 41 ^ 2 = 1681
# [2023-08-06 14:25:54.694] 2303383967:16 INFO - w 42 ^ 2 = 1764
# [2023-08-06 14:25:54.695] 2303383967:16 INFO - w 43 ^ 2 = 1849
# [2023-08-06 14:25:54.695] 2303383967:16 INFO - w 44 ^ 2 = 1936
# [2023-08-06 14:25:54.696] 2303383967:16 INFO - w 45 ^ 2 = 2025
# [2023-08-06 14:25:54.696] 2303383967:16 INFO - w 46 ^ 2 = 2116
# [2023-08-06 14:25:54.696] 2303383967:16 INFO - w 47 ^ 2 = 2209
# [2023-08-06 14:25:54.697] 2303383967:16 INFO - w 48 ^ 2 = 2304
# [2023-08-06 14:25:54.697] 2303383967:16 INFO - w 49 ^ 2 = 2401
# [2023-08-06 14:25:54.697] 2303383967:16 INFO - w 50 ^ 2 = 2500
# [2023-08-06 14:25:54.698] 2303383967:18 INFO - weather ok
# [2023-08-06 14:25:54.698] 2303383967:32 INFO - Stocks: {'stocks': []}
# [2023-08-06 14:25:54.698] 2303383967:34 INFO - Weather: {'weather': {}}
# [2023-08-06 14:25:54.699] 2303383967:35 INFO - Done

# %%
from random import randint


async def get_stock(name: str) -> int:
    log.info("Get stock %r", name)
    await asyncio.sleep(1)
    price = randint(1, 500)
    log.info("got stock %r for %s", name, price)
    return {"name": name, "price": price}


async def get_n_stocks(n_stock: int):
    log.info("get %s stocks", n_stock)
    tasks = {
        asyncio.create_task(
            get_stock(name=f"A{i:03}"),
            name=f"get-stock-{i}",
        )
        for i in range(1, n_stock + 1)
    }
    await asyncio.wait(tasks)
    log.info("done get %s stocks", n_stock)


async def main():
    await get_n_stocks(10)


await main()
# Out:
# [2023-08-06 14:39:03.776] 254082753:13 INFO - get 10 stocks
# [2023-08-06 14:39:03.778] 254082753:5 INFO - Get stock 'A001'
# [2023-08-06 14:39:03.779] 254082753:5 INFO - Get stock 'A002'
# [2023-08-06 14:39:03.783] 254082753:5 INFO - Get stock 'A003'
# [2023-08-06 14:39:03.791] 254082753:5 INFO - Get stock 'A004'
# [2023-08-06 14:39:03.791] 254082753:5 INFO - Get stock 'A005'
# [2023-08-06 14:39:03.792] 254082753:5 INFO - Get stock 'A006'
# [2023-08-06 14:39:03.793] 254082753:5 INFO - Get stock 'A007'
# [2023-08-06 14:39:03.794] 254082753:5 INFO - Get stock 'A008'
# [2023-08-06 14:39:03.795] 254082753:5 INFO - Get stock 'A009'
# [2023-08-06 14:39:03.795] 254082753:5 INFO - Get stock 'A010'
# [2023-08-06 14:39:04.780] 254082753:8 INFO - got stock 'A001' for 290
# [2023-08-06 14:39:04.784] 254082753:8 INFO - got stock 'A002' for 38
# [2023-08-06 14:39:04.791] 254082753:8 INFO - got stock 'A003' for 437
# [2023-08-06 14:39:04.792] 254082753:8 INFO - got stock 'A004' for 98
# [2023-08-06 14:39:04.793] 254082753:8 INFO - got stock 'A005' for 406
# [2023-08-06 14:39:04.794] 254082753:8 INFO - got stock 'A006' for 418
# [2023-08-06 14:39:04.795] 254082753:8 INFO - got stock 'A007' for 327
# [2023-08-06 14:39:04.799] 254082753:8 INFO - got stock 'A008' for 195
# [2023-08-06 14:39:04.805] 254082753:8 INFO - got stock 'A009' for 474
# [2023-08-06 14:39:04.808] 254082753:8 INFO - got stock 'A010' for 305
# [2023-08-06 14:39:04.809] 254082753:22 INFO - done get 10 stocks

# %%
from random import randint, random


async def get_stock(name: str) -> int:
    log.info("Get stock %r", name)
    to_sleep = random()
    await asyncio.sleep(to_sleep)
    price = randint(1, 500)
    log.info("got stock %r for %s", name, price)
    return {"name": name, "price": price}


async def get_n_stocks(n_stock: int):
    log.info("get %s stocks", n_stock)
    tasks = {
        asyncio.create_task(
            get_stock(name=f"A{i:03}"),
            name=f"get-stock-{i}",
        )
        for i in range(1, n_stock + 1)
    }
    await asyncio.wait(tasks)
    log.info("done get %s stocks", n_stock)


async def main():
    await get_n_stocks(10)


await main()
# Out:
# [2023-08-06 14:42:25.531] 542643613:14 INFO - get 10 stocks
# [2023-08-06 14:42:25.533] 542643613:5 INFO - Get stock 'A001'
# [2023-08-06 14:42:25.536] 542643613:5 INFO - Get stock 'A002'
# [2023-08-06 14:42:25.538] 542643613:5 INFO - Get stock 'A003'
# [2023-08-06 14:42:25.539] 542643613:5 INFO - Get stock 'A004'
# [2023-08-06 14:42:25.539] 542643613:5 INFO - Get stock 'A005'
# [2023-08-06 14:42:25.540] 542643613:5 INFO - Get stock 'A006'
# [2023-08-06 14:42:25.540] 542643613:5 INFO - Get stock 'A007'
# [2023-08-06 14:42:25.541] 542643613:5 INFO - Get stock 'A008'
# [2023-08-06 14:42:25.542] 542643613:5 INFO - Get stock 'A009'
# [2023-08-06 14:42:25.542] 542643613:5 INFO - Get stock 'A010'
# [2023-08-06 14:42:25.600] 542643613:9 INFO - got stock 'A007' for 131
# [2023-08-06 14:42:25.659] 542643613:9 INFO - got stock 'A001' for 467
# [2023-08-06 14:42:25.725] 542643613:9 INFO - got stock 'A004' for 473
# [2023-08-06 14:42:26.085] 542643613:9 INFO - got stock 'A002' for 419
# [2023-08-06 14:42:26.116] 542643613:9 INFO - got stock 'A009' for 64
# [2023-08-06 14:42:26.152] 542643613:9 INFO - got stock 'A003' for 166
# [2023-08-06 14:42:26.173] 542643613:9 INFO - got stock 'A005' for 461
# [2023-08-06 14:42:26.205] 542643613:9 INFO - got stock 'A006' for 239
# [2023-08-06 14:42:26.243] 542643613:9 INFO - got stock 'A010' for 252
# [2023-08-06 14:42:26.381] 542643613:9 INFO - got stock 'A008' for 85
# [2023-08-06 14:42:26.388] 542643613:23 INFO - done get 10 stocks

# %%
from random import randint, random


async def get_stock(name: str) -> int:
    log.info("Get stock %r", name)
    to_sleep = random()
    await asyncio.sleep(to_sleep)
    if random() > 0.4:
        log.warning("get stock %s error", name)
        raise ValueError(name)
    price = randint(1, 500)
    log.info("got stock %r for %s", name, price)
    return {"name": name, "price": price}


async def get_n_stocks(n_stock: int):
    log.info("get %s stocks", n_stock)
    tasks = {
        asyncio.create_task(
            get_stock(name=f"A{i:03}"),
            name=f"get-stock-{i}",
        )
        for i in range(1, n_stock + 1)
    }
    await asyncio.wait(tasks)
    log.info("done get %s stocks", n_stock)


async def main():
    await get_n_stocks(10)


await main()
# Out:
# [2023-08-06 14:44:27.663] 2665014786:17 INFO - get 10 stocks
# [2023-08-06 14:44:27.667] 2665014786:5 INFO - Get stock 'A001'
# [2023-08-06 14:44:27.669] 2665014786:5 INFO - Get stock 'A002'
# [2023-08-06 14:44:27.669] 2665014786:5 INFO - Get stock 'A003'
# [2023-08-06 14:44:27.670] 2665014786:5 INFO - Get stock 'A004'
# [2023-08-06 14:44:27.670] 2665014786:5 INFO - Get stock 'A005'
# [2023-08-06 14:44:27.671] 2665014786:5 INFO - Get stock 'A006'
# [2023-08-06 14:44:27.672] 2665014786:5 INFO - Get stock 'A007'
# [2023-08-06 14:44:27.673] 2665014786:5 INFO - Get stock 'A008'
# [2023-08-06 14:44:27.675] 2665014786:5 INFO - Get stock 'A009'
# [2023-08-06 14:44:27.677] 2665014786:5 INFO - Get stock 'A010'
# [2023-08-06 14:44:27.704] 2665014786:9 WARNING - get stock A009 error
# [2023-08-06 14:44:27.734] 2665014786:12 INFO - got stock 'A001' for 265
# [2023-08-06 14:44:28.165] 2665014786:9 WARNING - get stock A007 error
# [2023-08-06 14:44:28.299] 2665014786:9 WARNING - get stock A010 error
# [2023-08-06 14:44:28.417] 2665014786:9 WARNING - get stock A004 error
# [2023-08-06 14:44:28.445] 2665014786:12 INFO - got stock 'A008' for 297
# [2023-08-06 14:44:28.490] 2665014786:12 INFO - got stock 'A002' for 198
# [2023-08-06 14:44:28.580] 2665014786:9 WARNING - get stock A006 error
# [2023-08-06 14:44:28.582] 2665014786:9 WARNING - get stock A003 error
# [2023-08-06 14:44:28.592] 2665014786:12 INFO - got stock 'A005' for 265
# [2023-08-06 14:44:28.598] 2665014786:26 INFO - done get 10 stocks
# [2023-08-06 14:44:28.599] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-7' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A007')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A007
# [2023-08-06 14:44:28.601] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-10' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A010')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A010
# [2023-08-06 14:44:28.602] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-3' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A003')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A003
# [2023-08-06 14:44:28.603] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-6' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A006')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A006
# [2023-08-06 14:44:28.613] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-9' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A009')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A009
# [2023-08-06 14:44:28.616] base_events:1771 ERROR - Task exception was never retrieved
# future: <Task finished name='get-stock-4' coro=<get_stock() done, defined at /var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py:4> exception=ValueError('A004')>
# Traceback (most recent call last):
#   File "/var/folders/r0/f247yh3j4djfkghshd5yf41m0000gn/T/ipykernel_4945/2665014786.py", line 10, in get_stock
#     raise ValueError(name)
# ValueError: A004

# %%
async def get_n_stocks(n_stock: int):
    log.info("get %s stocks", n_stock)
    tasks = {
        asyncio.create_task(
            get_stock(name=f"A{i:03}"),
            name=f"get-stock-{i}",
        )
        for i in range(1, n_stock + 1)
    }
    done, pending = await asyncio.wait(tasks)
    log.info("done get %s stocks", n_stock)

    for task in pending:
        task.cancel()

    for task in done:
        result = task.result()
        log.info("task %s result: %s", task.get_name(), result)
    
    log.info("done")



async def main():
    await get_n_stocks(10)


await main()
# Out:
# [2023-08-06 14:48:11.228] 2138041099:2 INFO - get 10 stocks
# [2023-08-06 14:48:11.231] 2665014786:5 INFO - Get stock 'A001'
# [2023-08-06 14:48:11.236] 2665014786:5 INFO - Get stock 'A002'
# [2023-08-06 14:48:11.239] 2665014786:5 INFO - Get stock 'A003'
# [2023-08-06 14:48:11.240] 2665014786:5 INFO - Get stock 'A004'
# [2023-08-06 14:48:11.241] 2665014786:5 INFO - Get stock 'A005'
# [2023-08-06 14:48:11.241] 2665014786:5 INFO - Get stock 'A006'
# [2023-08-06 14:48:11.242] 2665014786:5 INFO - Get stock 'A007'
# [2023-08-06 14:48:11.242] 2665014786:5 INFO - Get stock 'A008'
# [2023-08-06 14:48:11.244] 2665014786:5 INFO - Get stock 'A009'
# [2023-08-06 14:48:11.245] 2665014786:5 INFO - Get stock 'A010'
# [2023-08-06 14:48:11.247] 2665014786:12 INFO - got stock 'A003' for 451
# [2023-08-06 14:48:11.258] 2665014786:12 INFO - got stock 'A008' for 204
# [2023-08-06 14:48:11.262] 2665014786:9 WARNING - get stock A002 error
# [2023-08-06 14:48:11.277] 2665014786:12 INFO - got stock 'A009' for 269
# [2023-08-06 14:48:11.673] 2665014786:12 INFO - got stock 'A006' for 2
# [2023-08-06 14:48:11.820] 2665014786:9 WARNING - get stock A001 error
# [2023-08-06 14:48:11.875] 2665014786:12 INFO - got stock 'A010' for 66
# [2023-08-06 14:48:11.962] 2665014786:9 WARNING - get stock A004 error
# [2023-08-06 14:48:11.966] 2665014786:9 WARNING - get stock A005 error
# [2023-08-06 14:48:12.050] 2665014786:9 WARNING - get stock A007 error
# [2023-08-06 14:48:12.051] 2138041099:16 INFO - task get-stock-6 result: {'name': 'A006', 'price': 2}
# /Users/suren/.pyenv/versions/3.11.4/lib/python3.11/re/__init__.py:258: RuntimeWarning: coroutine 'get_stocks' was never awaited
#   return pattern.translate(_special_chars_map)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 24
#      20 async def main():
#      21     await get_n_stocks(10)
# ---> 24 await main()
#
# Cell In[19], line 21, in main()
#      20 async def main():
# ---> 21     await get_n_stocks(10)
#
# Cell In[19], line 15, in get_n_stocks(n_stock)
#      12     task.cancel()
#      14 for task in done:
# ---> 15     result = task.result()
#      16     log.info("task %s result: %s", task.get_name(), result)
#      17 log.info("done get %s stocks", n_stock)
#
# Cell In[18], line 10, in get_stock(name)
#       8 if random() > 0.4:
#       9     log.warning("get stock %s error", name)
# ---> 10     raise ValueError(name)
#      11 price = randint(1, 500)
#      12 log.info("got stock %r for %s", name, price)
#
# ValueError: A001

# %%
async def get_n_stocks(n_stock: int):
    log.info("get %s stocks", n_stock)
    tasks = {
        asyncio.create_task(
            get_stock(name=f"A{i:03}"),
            name=f"get-stock-{i}",
        )
        for i in range(1, n_stock + 1)
    }
    done, pending = await asyncio.wait(tasks)
    log.info("done get %s stocks", n_stock)

    for task in pending:
        task.cancel()

    for task in done:
        error = task.exception()
        if error:
            log.warning(
                "task %s error %s",
                task.get_name(),
                error,
                # exc_info=error,
            )
            continue
        result = task.result()
        log.info("task %s result: %s", task.get_name(), result)
    
    log.info("done")



async def main():
    await get_n_stocks(10)


await main()
# Out:
# [2023-08-06 14:50:59.473] 1011841497:2 INFO - get 10 stocks
# [2023-08-06 14:50:59.477] 2665014786:5 INFO - Get stock 'A001'
# [2023-08-06 14:50:59.485] 2665014786:5 INFO - Get stock 'A002'
# [2023-08-06 14:50:59.487] 2665014786:5 INFO - Get stock 'A003'
# [2023-08-06 14:50:59.488] 2665014786:5 INFO - Get stock 'A004'
# [2023-08-06 14:50:59.488] 2665014786:5 INFO - Get stock 'A005'
# [2023-08-06 14:50:59.490] 2665014786:5 INFO - Get stock 'A006'
# [2023-08-06 14:50:59.490] 2665014786:5 INFO - Get stock 'A007'
# [2023-08-06 14:50:59.491] 2665014786:5 INFO - Get stock 'A008'
# [2023-08-06 14:50:59.491] 2665014786:5 INFO - Get stock 'A009'
# [2023-08-06 14:50:59.491] 2665014786:5 INFO - Get stock 'A010'
# [2023-08-06 14:50:59.581] 2665014786:12 INFO - got stock 'A004' for 324
# [2023-08-06 14:50:59.817] 2665014786:12 INFO - got stock 'A003' for 487
# [2023-08-06 14:50:59.967] 2665014786:9 WARNING - get stock A005 error
# [2023-08-06 14:51:00.014] 2665014786:12 INFO - got stock 'A009' for 88
# [2023-08-06 14:51:00.037] 2665014786:9 WARNING - get stock A002 error
# [2023-08-06 14:51:00.044] 2665014786:12 INFO - got stock 'A001' for 480
# [2023-08-06 14:51:00.064] 2665014786:9 WARNING - get stock A006 error
# [2023-08-06 14:51:00.154] 2665014786:9 WARNING - get stock A010 error
# [2023-08-06 14:51:00.169] 2665014786:12 INFO - got stock 'A007' for 440
# [2023-08-06 14:51:00.227] 2665014786:9 WARNING - get stock A008 error
# [2023-08-06 14:51:00.229] 1011841497:11 INFO - done get 10 stocks
# [2023-08-06 14:51:00.230] 1011841497:19 WARNING - task get-stock-5 error A005
# [2023-08-06 14:51:00.235] 1011841497:19 WARNING - task get-stock-8 error A008
# [2023-08-06 14:51:00.237] 1011841497:27 INFO - task get-stock-9 result: {'name': 'A009', 'price': 88}
# [2023-08-06 14:51:00.241] 1011841497:27 INFO - task get-stock-3 result: {'name': 'A003', 'price': 487}
# [2023-08-06 14:51:00.242] 1011841497:19 WARNING - task get-stock-6 error A006
# [2023-08-06 14:51:00.242] 1011841497:27 INFO - task get-stock-1 result: {'name': 'A001', 'price': 480}
# [2023-08-06 14:51:00.243] 1011841497:27 INFO - task get-stock-4 result: {'name': 'A004', 'price': 324}
# [2023-08-06 14:51:00.244] 1011841497:19 WARNING - task get-stock-2 error A002
# [2023-08-06 14:51:00.245] 1011841497:19 WARNING - task get-stock-10 error A010
# [2023-08-06 14:51:00.245] 1011841497:27 INFO - task get-stock-7 result: {'name': 'A007', 'price': 440}
# [2023-08-06 14:51:00.247] 1011841497:29 INFO - done
